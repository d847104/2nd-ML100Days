# %% [markdown]
# ## 作業1：
#
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# #### 選擇資料:https://www.kaggle.com/c/two-sigma-financial-news
#
# #### 1. 你選的這組資料為何重要
#
# #### 此組資料透過新聞數據，有效地預測股價趨勢，雖說不一定正確，但有一定參考性。
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# #### Data for this competition comes from the following sources:
#
# #### Market data provided by Intrinio.
# #### News data provided by Thomson Reuters. Copyright Thomson Reuters, 2017. All Rights Reserved. Use, duplication, or sale of this service, or data contained herein, except as described in the Competition Rules, is strictly prohibited.
#
# #### 3. 蒐集而來的資料型態為何
#
# #### 結構化資料，如股價資料。
#
# #### 4. 這組資料想解決的問題如何評估
#
# #### 透過回歸分析，進而分析股價是否存在顯著差異。
#
#
# ## 作業2：
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# #### 如何有效地提高載客效率、增加車輛流動效率，進而提升業績。假設每月客流量皆為固定。
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# #### 將車隊旗下車輛每日載客數量、地點透過電子化之方式，分析高峰及谷底，進而分析乘客偏好。
#
# #### 3. 蒐集而來的資料型態為何
#
# #### 結構性資料。
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# #### 特過數據化之分析、可觀察出乘客流量高、低時段，熱門區域、冷門區域，進而估計出每月平均客流量。
#
# ## 作業3：

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.505

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    square_error = (y - y_hat) ** 2
    return sum(square_error) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 225.597
# The Mean absolute error is 12.229
